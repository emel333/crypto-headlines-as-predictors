# %%
! pip install -U spacy
! python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.0.6-cp36-cp36m-win_amd64.whl (11.7 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (20.8)
# Requirement already satisfied: jinja2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: setuptools in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (51.0.0.post20201207)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (4.55.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (1.19.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy) (2.25.1)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp36-cp36m-win_amd64.whl (6.5 MB)
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy) (3.4.0)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp36-cp36m-win_amd64.whl (35 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp36-cp36m-win_amd64.whl (20 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.5.2-py3-none-any.whl (42 kB)
# Collecting dataclasses<1.0,>=0.6
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp36-cp36m-win_amd64.whl (109 kB)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.4-cp36-cp36m-win_amd64.whl (1.7 MB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.5-py2.py3-none-any.whl (12 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp36-cp36m-win_amd64.whl (450 kB)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.3-cp36-cp36m-win_amd64.whl (1.0 MB)
# Collecting contextvars<3,>=2.4
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.15-cp36-cp36m-win_amd64.whl (56 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from jinja2->spacy) (1.1.1)
# Building wheels for collected packages: smart-open, contextvars
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=d6c7fd8559a25eef2037ffa3f584cfdf23decbd77f584d07b3835cb27300154e
#   Stored in directory: c:\users\samsung\appdata\local\pip\cache\wheels\88\2a\d4\f2e9023989d4d4b3574f268657cb6cd23994665a038803f547
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=bae74faa5aec960b61641e2301204efe25fb3073c97857c2903c21d42efc293d
#   Stored in directory: c:\users\samsung\appdata\local\pip\cache\wheels\41\11\53\911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built smart-open contextvars
# Installing collected packages: typing-extensions, murmurhash, immutables, dataclasses, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, contextvars, blis, thinc, spacy-legacy, pathy, spacy
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 1.8.4
#     Uninstalling smart-open-1.8.4:
#       Successfully uninstalled smart-open-1.8.4
# Successfully installed blis-0.7.4 catalogue-2.0.4 contextvars-2.4 cymem-2.0.5 dataclasses-0.8 immutables-0.15 murmurhash-1.0.5 pathy-0.5.2 preshed-3.0.5 pydantic-1.7.4 smart-open-3.0.0 spacy-3.0.6 spacy-legacy-3.0.5 srsly-2.4.1 thinc-8.0.3 typer-0.3.2 typing-extensions-3.10.0.0 wasabi-0.8.2
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (51.0.0.post20201207)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.55.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10.0.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: jinja2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: contextvars<3,>=2.4 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from thinc<8.1.0,>=8.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4)
# Requirement already satisfied: immutables>=0.9 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.15)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\samsung\anaconda3\envs\learn-env\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.0.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\samsung\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("We started from the bottom, but now we are here.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['We', 'the bottom', 'we']
# Verbs: ['start', 'be']
